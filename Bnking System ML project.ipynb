# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\bank\bank-full.csv',delimiter=';')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.shape
# Out:
# (45211, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
# handle null values

df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
#Representing

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# # Visualize the dataset
# Let us see the count of each type of job.

# %%
df['job'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
# lets see number of job type
no_of_job=df['job'].value_counts()
no_of_job
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64

# %%
# represinting by graph
no_of_job.plot(kind='bar',color='red')
plt.title("Type of Job Distribution")
# Out:
# Text(0.5, 1.0, 'Type of Job Distribution')

# %%
# seeing merital status
merital_status_count=df['marital'].value_counts()
merital_status_count
# Out:
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64

# %%
# representing by graph
merital_status_count.plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='marital'>

# %%
#Reslt-- here is married status is more than single and divorced

# %%
# how many types of education in data set

education_count=df['education'].value_counts()
education_count
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
#represeting by graph

education_count.plot(kind='bar',color='r')
# Out:
# <AxesSubplot:>

# %%
# how many customer has  personal loan or not?

personal_loan_count=df['loan'].value_counts()
personal_loan_count
# Out:
# no     37967
# yes     7244
# Name: loan, dtype: int64

# %%
# representing bygraph
personal_loan_count.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Result-- some customer has taken  personal loan

# %%
# how many customer has  housing loan or not?

# %%
house_loan_count=df['housing'].value_counts()
house_loan_count
# Out:
# yes    25130
# no     20081
# Name: housing, dtype: int64

# %%
# representing by graph

house_loan_count.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Result-- max number of customer has taken house loan

# %%
# how many people connect cellular or telephinic

contact_count=df['contact'].value_counts()
contact_count
# Out:
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64

# %%
# representiong  by graph
contact_count.plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='contact'>

# %%
#Result--max customer  were contacted by cellular

# %%
# how many customer connect by months wise

months_customer_count=df['month'].value_counts()
months_customer_count
# Out:
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64

# %%
# representing by graph

months_customer_count.plot(kind='bar',color='b')
# Out:
# <AxesSubplot:>

# %%
# result-- max custome has come in may and min customer come in dec

# %%
# find top 5 maxcustomer connect by date wise
date_wise_customer=df['day'].value_counts().head()
date_wise_customer
# Out:
# 20    2752
# 18    2308
# 21    2026
# 17    1939
# 6     1932
# Name: day, dtype: int64

# %%
#representing by graph
date_wise_customer.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # change categorical to numerical

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df1=df[['education','month']]

# %%
df1
# Out:
#        education month
# 0       tertiary   may
# 1      secondary   may
# 2      secondary   may
# 3        unknown   may
# 4        unknown   may
# ...          ...   ...
# 45206   tertiary   nov
# 45207    primary   nov
# 45208  secondary   nov
# 45209  secondary   nov
# 45210  secondary   nov
#
# [45211 rows x 2 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
x_train = df1[['education','month']]

# %%
x_train
# Out:
#        education month
# 0       tertiary   may
# 1      secondary   may
# 2      secondary   may
# 3        unknown   may
# 4        unknown   may
# ...          ...   ...
# 45206   tertiary   nov
# 45207    primary   nov
# 45208  secondary   nov
# 45209  secondary   nov
# 45210  secondary   nov
#
# [45211 rows x 2 columns]

# %%
oe = OrdinalEncoder()

# %%
oe.fit(x_train)
# Out:
# OrdinalEncoder()

# %%
x_train = oe.transform(x_train)

# %%
x_train
# Out:
# array([[2., 8.],
#        [1., 8.],
#        [1., 8.],
#        ...,
#        [1., 9.],
#        [1., 9.],
#        [1., 9.]])

# %%
data_frame=pd.DataFrame(x_train,columns=df1.columns)

# %%
data_frame
# Out:
#        education  month
# 0            2.0    8.0
# 1            1.0    8.0
# 2            1.0    8.0
# 3            3.0    8.0
# 4            3.0    8.0
# ...          ...    ...
# 45206        2.0    9.0
# 45207        0.0    9.0
# 45208        1.0    9.0
# 45209        1.0    9.0
# 45210        1.0    9.0
#
# [45211 rows x 2 columns]

# %%
df2=df.drop(['education','month'],axis=True)

# %%
df2
# Out:
#        age           job   marital default  balance housing loan    contact  \
# 0       58    management   married      no     2143     yes   no    unknown
# 1       44    technician    single      no       29     yes   no    unknown
# 2       33  entrepreneur   married      no        2     yes  yes    unknown
# 3       47   blue-collar   married      no     1506     yes   no    unknown
# 4       33       unknown    single      no        1      no   no    unknown
# ...    ...           ...       ...     ...      ...     ...  ...        ...
# 45206   51    technician   married      no      825      no   no   cellular
# 45207   71       retired  divorced      no     1729      no   no   cellular
# 45208   72       retired   married      no     5715      no   no   cellular
# 45209   57   blue-collar   married      no      668      no   no  telephone
# 45210   37  entrepreneur   married      no     2971      no   no   cellular
#
# ...

# %%
df = pd.concat([df2,data_frame],axis = 1,)

# %%
df
# Out:
#        age           job   marital default  balance housing loan    contact  \
# 0       58    management   married      no     2143     yes   no    unknown
# 1       44    technician    single      no       29     yes   no    unknown
# 2       33  entrepreneur   married      no        2     yes  yes    unknown
# 3       47   blue-collar   married      no     1506     yes   no    unknown
# 4       33       unknown    single      no        1      no   no    unknown
# ...    ...           ...       ...     ...      ...     ...  ...        ...
# 45206   51    technician   married      no      825      no   no   cellular
# 45207   71       retired  divorced      no     1729      no   no   cellular
# 45208   72       retired   married      no     5715      no   no   cellular
# 45209   57   blue-collar   married      no      668      no   no  telephone
# 45210   37  entrepreneur   married      no     2971      no   no   cellular
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'default', 'balance', 'housing', 'loan',
#        'contact', 'day', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome', 'y', 'education', 'month'],
#       dtype='object')

# %%
df = pd.concat([df,new_df],axis = 1,)

# %%
df
# Out:
#        age           job   marital default  balance housing loan    contact  \
# 0       58    management   married      no     2143     yes   no    unknown
# 1       44    technician    single      no       29     yes   no    unknown
# 2       33  entrepreneur   married      no        2     yes  yes    unknown
# 3       47   blue-collar   married      no     1506     yes   no    unknown
# 4       33       unknown    single      no        1      no   no    unknown
# ...    ...           ...       ...     ...      ...     ...  ...        ...
# 45206   51    technician   married      no      825      no   no   cellular
# 45207   71       retired  divorced      no     1729      no   no   cellular
# 45208   72       retired   married      no     5715      no   no   cellular
# 45209   57   blue-collar   married      no      668      no   no  telephone
# 45210   37  entrepreneur   married      no     2971      no   no   cellular
#
# ...

# %%
df=df.drop(['job','marital','default','housing','loan','contact'],axis=1)

# %%
df
# Out:
#        age  balance  day  duration  campaign  pdays  previous poutcome    y  \
# 0       58     2143    5       261         1     -1         0  unknown   no
# 1       44       29    5       151         1     -1         0  unknown   no
# 2       33        2    5        76         1     -1         0  unknown   no
# 3       47     1506    5        92         1     -1         0  unknown   no
# 4       33        1    5       198         1     -1         0  unknown   no
# ...    ...      ...  ...       ...       ...    ...       ...      ...  ...
# 45206   51      825   17       977         3     -1         0  unknown  yes
# 45207   71     1729   17       456         2     -1         0  unknown  yes
# 45208   72     5715   17      1127         5    184         3  success  yes
# 45209   57      668   17       508         4     -1         0  unknown   no
# 45210   37     2971   17       361         2    188        11    other   no
#
# ...

# %%
df=df.drop(['poutcome','y'],axis=1)

# %%
df
# Out:
#        age  balance  day  duration  campaign  pdays  previous  education  \
# 0       58     2143    5       261         1     -1         0        2.0
# 1       44       29    5       151         1     -1         0        1.0
# 2       33        2    5        76         1     -1         0        1.0
# 3       47     1506    5        92         1     -1         0        3.0
# 4       33        1    5       198         1     -1         0        3.0
# ...    ...      ...  ...       ...       ...    ...       ...        ...
# 45206   51      825   17       977         3     -1         0        2.0
# 45207   71     1729   17       456         2     -1         0        0.0
# 45208   72     5715   17      1127         5    184         3        1.0
# 45209   57      668   17       508         4     -1         0        1.0
# 45210   37     2971   17       361         2    188        11        1.0
#
#        month  job_blue-collar  ...  marital_single  default_yes  housing_yes  \
# ...

# %%
# divided into train test split

x= df.drop('y_yes',axis=True)

# %%
x
# Out:
#        age  balance  day  duration  campaign  pdays  previous  education  \
# 0       58     2143    5       261         1     -1         0        2.0
# 1       44       29    5       151         1     -1         0        1.0
# 2       33        2    5        76         1     -1         0        1.0
# 3       47     1506    5        92         1     -1         0        3.0
# 4       33        1    5       198         1     -1         0        3.0
# ...    ...      ...  ...       ...       ...    ...       ...        ...
# 45206   51      825   17       977         3     -1         0        2.0
# 45207   71     1729   17       456         2     -1         0        0.0
# 45208   72     5715   17      1127         5    184         3        1.0
# 45209   57      668   17       508         4     -1         0        1.0
# 45210   37     2971   17       361         2    188        11        1.0
#
#        month  job_blue-collar  ...  marital_married  marital_single  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(x)
# Out:
# StandardScaler()

# %%
x
# Out:
#        age  balance  day  duration  campaign  pdays  previous  education  \
# 0       58     2143    5       261         1     -1         0        2.0
# 1       44       29    5       151         1     -1         0        1.0
# 2       33        2    5        76         1     -1         0        1.0
# 3       47     1506    5        92         1     -1         0        3.0
# 4       33        1    5       198         1     -1         0        3.0
# ...    ...      ...  ...       ...       ...    ...       ...        ...
# 45206   51      825   17       977         3     -1         0        2.0
# 45207   71     1729   17       456         2     -1         0        0.0
# 45208   72     5715   17      1127         5    184         3        1.0
# 45209   57      668   17       508         4     -1         0        1.0
# 45210   37     2971   17       361         2    188        11        1.0
#
#        month  job_blue-collar  ...  marital_married  marital_single  \
# ...

# %%
y=df.y_yes

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
# Name: y_yes, Length: 45211, dtype: uint8

# %% [markdown]
# # logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\saura\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94     11966
#            1       0.55      0.20      0.29      1598
#
#     accuracy                           0.89     13564
#    macro avg       0.73      0.59      0.62     13564
# weighted avg       0.86      0.89      0.86     13564

# %%
from sklearn import metrics

# %%
metrics.confusion_matrix(y_true = y_test,y_pred = pred)
# Out:
# array([[11705,   261],
#        [ 1280,   318]], dtype=int64)

# %%
# print other matrix
# accuracy----> 
print("Accuracy",metrics.accuracy_score(y_test,pred))
# Out:
# Accuracy 0.8863904452963728

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pred=knn.predict(x_test)

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Accuracy Score:",accuracy_score(y_test,pred))
# Out:
# Accuracy Score: 0.8790917133588911

# %% [markdown]
# # SVM
