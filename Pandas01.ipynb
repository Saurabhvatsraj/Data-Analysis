# %%
import pandas as pd

# %%
x={
    'name':['saurabh','ankit','ajay'],
    'age':[23,12,45],
    'marks':[234,56,78]
}

# %%
x
# Out:
# {'name': ['saurabh', 'ankit', 'ajay'],
#  'age': [23, 12, 45],
#  'marks': [234, 56, 78]}

# %%
type(x)
# Out:
# dict

# %%
# how to make data frame
df=pd.DataFrame(x)

# %%
df
# Out:
#       name  age  marks
# 0  saurabh   23    234
# 1    ankit   12     56
# 2     ajay   45     78

# %%
df['name']
# Out:
# 0    saurabh
# 1      ankit
# 2       ajay
# Name: name, dtype: object

# %%
df['name'][0]='rohit'
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_19612\1545967261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['name'][0]='rohit'

# %%
df
# Out:
#     name  age  marks
# 0  rohit   23    234
# 1  ankit   12     56
# 2   ajay   45     78

# %%
df['marks'][2]=40
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_19612\2066339602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marks'][2]=40

# %%
df
# Out:
#     name  age  marks
# 0  rohit   23    234
# 1  ankit   12     56
# 2   ajay   45     40

# %%
# storing the data----
#use csv file to store the data
#read the files/store the file

file=df.to_csv("myfirstfile.csv")

# %%
file

# %%
#wap to store df into excel file
file=df.to_excel("mysecondfiles.xlsx",index=False)

# %%
file

# %%
# hoe to read data

df=pd.read_csv(r'C:\Users\saura\Downloads\Unicorn_Companies.csv')

# %%
df
# Out:
#            Company Valuation ($B) Date Joined        Country           City  \
# 0        Bytedance           $140    4/7/2017          China        Beijing
# 1           SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2           Stripe            $95   1/23/2014  United States  San Francisco
# 3           Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4       Epic Games            $42  10/26/2018  United States           Cary
# ...            ...            ...         ...            ...            ...
# 1032     Timescale             $1   2/22/2022  United States       New York
# 1033      Scalapay             $1   2/23/2022          Italy          Milan
# 1034  Omada Health             $1   2/23/2022  United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022  United States       New York
# 1036          Veev             $1   2/24/2022  United States      San Mateo
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2                          Fintech
# 3                          Fintech
# 4                            Other
# ...                            ...
# 1032  Internet software & services
# 1033                       Fintech
# 1034                        Health
# 1035                 Cybersecurity
# 1036  Internet software & services
#
#                                       Select Inverstors Founded Year  \
# 0     Sequoia Capital China, SIG Asia Investments, S...         2012
# 1     Founders Fund, Draper Fisher Jurvetson, Rothen...         2002
# 2           Khosla Ventures, LowercaseCapital, capitalG         2010
# 3     Institutional Venture Partners, Sequoia Capita...         2005
# 4                 Tencent Holdings, KKR, Smash Ventures         1991
# ...                                                 ...          ...
# 1032  New Enterprise Associates, Benchmark, Two Sigm...         2015
# 1033  Fasanara Capital, Tiger Global Management, Bal...         2019
# 1034  U.S. Venture Partners, dRx Capital, Andreessen...         2011
# 1035  8VC, Liberty Strategic Capital, Eden Global Pa...         2017
# 1036           Zeev Ventures, Bond, Fifth Wall Ventures         2008
#
#      Total Raised Financial Stage Investors Count Deal Terms Portfolio Exits
# 0          $7.44B             IPO              28          8               5
# 1         $6.874B            None              29         12            None
# 2         $2.901B           Asset              39         12               1
# 3         $3.472B        Acquired              56         13               1
# 4         $4.377B        Acquired              25          5               2
# ...           ...             ...             ...        ...             ...
# 1032     $181.06M            None               7          2            None
# 1033        $700M            None              10          2            None
# 1034     $449.72M            None              30          6            None
# 1035      $525.5M            None               6          2            None
# 1036      $604.5M            None              11          1            None
#
# [1037 rows x 13 columns]

# %%
# head--- 5 uperdata
#tail---5 lower data
# sample----randomly any sample data

df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
#   Founded Year Total Raised Financial Stage Investors Count Deal Terms  \
# 0         2012       $7.44B             IPO              28          8
# 1         2002      $6.874B            None              29         12
# 2         2010      $2.901B           Asset              39         12
# 3         2005      $3.472B        Acquired              56         13
# 4         1991      $4.377B        Acquired              25          5
#
#   Portfolio Exits
# 0               5
# 1            None
# 2               1
# 3               1
# 4               2

# %%
df.tail()
# Out:
#            Company Valuation ($B) Date Joined        Country           City  \
# 1032     Timescale             $1   2/22/2022  United States       New York
# 1033      Scalapay             $1   2/23/2022          Italy          Milan
# 1034  Omada Health             $1   2/23/2022  United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022  United States       New York
# 1036          Veev             $1   2/24/2022  United States      San Mateo
#
#                           Industry  \
# 1032  Internet software & services
# 1033                       Fintech
# 1034                        Health
# 1035                 Cybersecurity
# 1036  Internet software & services
#
#                                       Select Inverstors Founded Year  \
# 1032  New Enterprise Associates, Benchmark, Two Sigm...         2015
# 1033  Fasanara Capital, Tiger Global Management, Bal...         2019
# 1034  U.S. Venture Partners, dRx Capital, Andreessen...         2011
# 1035  8VC, Liberty Strategic Capital, Eden Global Pa...         2017
# 1036           Zeev Ventures, Bond, Fifth Wall Ventures         2008
#
#      Total Raised Financial Stage Investors Count Deal Terms Portfolio Exits
# 1032     $181.06M            None               7          2            None
# 1033        $700M            None              10          2            None
# 1034     $449.72M            None              30          6            None
# 1035      $525.5M            None               6          2            None
# 1036      $604.5M            None              11          1            None

# %%
df.sample()
# Out:
#            Company Valuation ($B) Date Joined        Country           City  \
# 1034  Omada Health             $1   2/23/2022  United States  San Francisco
#
#      Industry                                  Select Inverstors Founded Year  \
# 1034   Health  U.S. Venture Partners, dRx Capital, Andreessen...         2011
#
#      Total Raised Financial Stage Investors Count Deal Terms Portfolio Exits
# 1034     $449.72M            None              30          6            None

# %%
df.sample(10)
# Out:
#              Company Valuation ($B) Date Joined        Country  \
# 592          Figment           $1.4  12/20/2021         Canada
# 915          EcoFlow             $1   6/10/2021          China
# 961  Keenon Robotics             $1   9/15/2021          China
# 916            Carro             $1   6/14/2021      Singapore
# 459             Rokt          $1.95  12/16/2021  United States
# 432             Opay             $2   8/23/2021        Nigeria
# 640   You & Mr Jones           $1.3  11/19/2019  United States
# 969     Chronosphere             $1   10/7/2021  United States
# 482   DispatchHealth           $1.7    3/3/2021  United States
# 360       Ankorstore          $2.26   1/10/2022         France
#
#                                 City  \
# 592                          Toronto
# 915                         Shenzhen
# 961                         Shanghai
# 916  E-commerce & direct-to-consumer
# 459                         New York
# 432                            Lagos
# 640                         New York
# 969                         New York
# 482                           Denver
# 360                            Paris
#
#                                               Industry  \
# 592                       Internet software & services
# 915                                           Hardware
# 961                Supply chain, logistics, & delivery
# 916  SingTel Innov8, Alpha JWC Ventures, Golden Gat...
# 459                       Internet software & services
# 432                                            Fintech
# 640                                              Other
# 969                        Data management & analytics
# 482                                             Health
# 360                    E-commerce & direct-to-consumer
#
#                                      Select Inverstors Founded Year  \
# 592      Bonfire Ventures, Two Sigma Ventures, FJ Labs         2018
# 915  Delian Capital, China International Capital Co...         2017
# 961   Yunqi Partners, SoftBank Group, iVision Ventures         2010
# 916                                               None         2015
# 459  Square Peg Capital, TDM Growth Partners, Tiger...         2012
# 432  Sequoia Capital China, Source Code Capital, Re...         2018
# 640                                        Undisclosed         None
# 969   Greylock Partners, Lux Capital, General Atlantic         2019
# 482  Alta Partners, Questa Capital, Echo Health Ven...         2013
# 360  Global Founders Capital, Aglae Ventures, Alven...         2019
#
#     Total Raised Financial Stage Investors Count Deal Terms Portfolio Exits
# 592     $163.84M            None              24          2            None
# 915     $110.59M            None              13          1            None
# 961     $228.79M            None              13          1            None
# 916     $684.52M            None              31          4            None
# 459      $488.5M            None              12          4            None
# 432        $570M            None              13          1            None
# 640      $1.013B            None              10          5            None
# 969     $255.34M            None               6          1            None
# 482     $406.96M            None               9          2            None
# 360     $420.89M            None               9          1            None
