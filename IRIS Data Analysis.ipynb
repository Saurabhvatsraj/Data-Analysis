# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# TASK1--Viz the null values of this data by analysis ans viz?

# %%
#by analysis-----

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#by viz--

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# result-----there is no nullvalue in this data

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# TASK 2- Find the max or min  sepal length by analysis and viz?

# %%
max_sepal_len=df.loc[df.sepal_length.max()==df.sepal_length][['species','sepal_length']]
max_sepal_len
# Out:
#        species  sepal_length
# 131  virginica           7.9

# %%
min_sepal_len=df.loc[df.sepal_length.min()==df.sepal_length][['species','sepal_length']]
min_sepal_len
# Out:
#    species  sepal_length
# 13  setosa           4.3

# %%
# max len of sepal by viz.

# %%
sns.jointplot(x='sepal_length',y='species',data=df)

# %%
#result----According to thr graph max len of sepal is"VIRGINICA"  and min len of sepal is"SETOSA"

# %%
# TASK 3 Find the max or min  sepal width by analysis and viz?

# %%
min_sepal_width=df[df['sepal_width'].min()==df['sepal_width']][['sepal_width','species']]
min_sepal_width
# Out:
#     sepal_width     species
# 60          2.0  versicolor

# %%
max_sepal_width=df[df['sepal_width'].max()==df['sepal_width']][['sepal_width','species']]
max_sepal_width
# Out:
#     sepal_width species
# 15          4.4  setosa

# %%
# max or min width of sepal by viz

# %%
sns.jointplot(x='sepal_width',y='species',data=df)

# %%
# result--According to thr graph max width of sepal is"SETOSA"  and min  width of sepal is"VERSICOLOR"

# %%
# TASK 4-Find max or min petal length  by analysis and viz?

max_petal_len=df.loc[df.petal_length.max()==df.petal_length][['petal_width','species']]
max_petal_len
# Out:
#      petal_width    species
# 118          2.3  virginica

# %%
min_petal_len=df.loc[df.petal_length.min()==df.petal_length][['petal_width','species']]
min_petal_len
# Out:
#     petal_width species
# 22          0.2  setosa

# %%
# max or min petal len by viz.

# %%
sns.barplot(x='species',y='petal_length',data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#result--According to the bar graph max len of petal is "VIRGINICA" min length of petal is"SETOSA"

# %%
# TASK 5  Find max or min petal width by analysis and viz.

max_petal_width=df[df.petal_width.max()==df.petal_width][['petal_width','species']].head(1)
max_petal_width
# Out:
#      petal_width    species
# 100          2.5  virginica

# %%
min_petal_width=df[df.petal_width.min()==df.petal_width][['petal_width','species']].head(1)
min_petal_width
# Out:
#    petal_width species
# 9          0.1  setosa

# %%
sns.barplot(x='species',y='petal_length',data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#result------ max width of petal is "VIRGINICA"  and min width of petal is "SETOSA"

# %%
# TASK 6 show the viz total number of sepal length and width petal length and width of SETOSA?

# %%
x1=df[df['species']=='setosa']['sepal_length'].sum()
x2=df[df['species']=='setosa']['sepal_width'].sum()
x3=df[df['species']=='setosa']['petal_length'].sum()
x4=df[df['species']=='setosa']['petal_width'].sum()
data=[x1,x2,x3,x4]
mylabels=['sepal_len','sepal_width','petal_len','petal_width']
plt.pie(data,labels=mylabels,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x15472c37460>,
# ...
#  [Text(0.022146381108345346, 1.0997770400421187, 'sepal_len'),
#   Text(-0.5742108590462341, -0.9382333874646468, 'sepal_width'),
#   Text(0.9045818745966164, -0.625884679594629, 'petal_len'),
#   Text(1.0968079076518147, -0.08374015591368643, 'petal_width')],
#  [Text(0.012079844240915643, 0.5998783854775193, '49.36'),
#   Text(-0.3132059231161277, -0.5117636658898073, '33.80'),
#   Text(0.493408295234518, -0.3413916434152522, '14.42'),
#   Text(0.5982588587191716, -0.0456764486801926, '2.43')])

# %%
#result-----

# %%
#TASK 7-Find the total count of setosa ,virginica and versicolor ?

# %%
total_number_setosa=df[df['species']=='setosa'].value_counts().sum()
total_number_setosa
# Out:
# 50

# %%
total_number_virginica=df[df['species']=='virginica'].value_counts().sum()
total_number_virginica
# Out:
# 50

# %%
total_number_versicolor=df[df['species']=='versicolor'].value_counts().sum()
total_number_versicolor
# Out:
# 50

# %%
# total count of setosa ,virginica and versicolor bvy viz

sns.countplot(x='species',data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
#result--total count of setosa ,virginica and versicolor  are same.

# %%
# TASK 8 Find a list whose sepal len is greater than 5 and sepal width is greater than 4.

# %%
df.loc[(df['sepal_length']>5)& (df['sepal_width']>4)][['species','sepal_length','sepal_width']]
# Out:
#    species  sepal_length  sepal_width
# 15  setosa           5.7          4.4
# 32  setosa           5.2          4.1
# 33  setosa           5.5          4.2

# %%
#TASK 9 show the viz total number of sepal length and width petal length and width of VIRGINICA?

# %%
x1=df[df['species']=='virginica']['sepal_length'].sum()
x2=df[df['species']=='virginica']['sepal_width'].sum()
x3=df[df['species']=='virginica']['petal_length'].sum()
x4=df[df['species']=='virginica']['petal_width'].sum()
data=[x1,x2,x3,x4]
mylabels=['sepal_len','sepal_width','petal_len','petal_width']
plt.pie(data,labels=mylabels,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x15473cb6eb0>,
# ...
#  [Text(0.390877302715045, 1.028209576994015, 'sepal_len'),
#   Text(-1.0819399572735728, 0.1985092664206377, 'sepal_width'),
#   Text(-0.20722811608759292, -1.080303896087942, 'petal_len'),
#   Text(1.0250240044237102, -0.39915634825865115, 'petal_width')],
#  [Text(0.21320580148093363, 0.5608415874512809, '38.44'),
#   Text(-0.590149067603767, 0.1082777816839842, '17.35'),
#   Text(-0.11303351786595975, -0.5892566705934229, '32.39'),
#   Text(0.5591040024129328, -0.2177216445047188, '11.82')])

# %%
#result----

# %%
# TASK 10--show the viz total number of sepal length and width petal length and width of VERSICOLOR?

# %%
x1=df[df['species']=='versicolor']['sepal_length'].sum()
x2=df[df['species']=='versicolor']['sepal_width'].sum()
x3=df[df['species']=='versicolor']['petal_length'].sum()
x4=df[df['species']=='versicolor']['petal_width'].sum()
data=[x1,x2,x3,x4]
mylabels=['sepal_len','sepal_width','petal_len','petal_width']
plt.pie(data,labels=mylabels,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x15473d182e0>,
# ...
#  [Text(0.28913609745733704, 1.0613200823253754, 'sepal_len'),
#   Text(-1.096746152481854, -0.08454511822837366, 'sepal_width'),
#   Text(0.05655528563901233, -1.098545174158209, 'petal_len'),
#   Text(1.0536033351652776, -0.31610126878676703, 'petal_width')],
#  [Text(0.15771059861309292, 0.5789018630865683, '41.53'),
#   Text(-0.5982251740810113, -0.046115519033658355, '19.38'),
#   Text(0.03084833762127945, -0.5992064586317504, '29.81'),
#   Text(0.5746927282719695, -0.1724188738836911, '9.28')])

# %%
#RESULT---

# %%
#TASK 11 Find the corelation between IRIS data set
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df,hue='species')
