# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
f1=pd.read_excel(r'C:\Users\saura\Downloads\archive (20)\data_dictionary.xlsx')
f1
# Out:
#                     Variable  \
# 0                        Age
# 1                  Attrition
# 2             BusinessTravel
# 3                 Department
# 4           DistanceFromHome
# 5                  Education
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10            EducationField
# 11             EmployeeCount
# 12            EmployeeNumber
# 13   EnvironmentSatisfaction
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                    Gender
# 18            JobInvolvement
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                  JobLevel
# 23                   JobRole
# 24           JobSatisfaction
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28             MaritalStatus
# 29             MonthlyIncome
# 30        NumCompaniesWorked
# ...

# %%
f1.isnull().sum()
# Out:
# Variable    22
# Meaning     22
# Levels      23
# dtype: int64

# %%
f2=pd.read_csv(r'C:\Users\saura\Downloads\archive (20)\employee_survey_data.csv')
f2
f2.isnull().sum()
# Out:
# EmployeeID                  0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# dtype: int64

# %%
f3=pd.read_csv(r'C:\Users\saura\Downloads\archive (20)\general_data.csv')
f3
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
f4=pd.read_csv(r'C:\Users\saura\Downloads\archive (20)\in_time.csv')
f4
# Out:
#       Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0              1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1              2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2              3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3              4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4              5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
# ...          ...         ...                  ...                  ...
# 4405        4406         NaN  2015-01-02 09:20:32  2015-01-05 10:17:53
# 4406        4407         NaN  2015-01-02 10:03:41                  NaN
# 4407        4408         NaN  2015-01-02 10:01:01  2015-01-05 09:33:00
# 4408        4409         NaN  2015-01-02 10:17:05  2015-01-05 10:02:27
# 4409        4410         NaN  2015-01-02 09:59:09  2015-01-05 10:16:14
#
#                2015-01-06           2015-01-07           2015-01-08  \
# ...

# %%
f5=pd.read_csv(r'C:\Users\saura\Downloads\archive (20)\manager_survey_data.csv')
f5
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating
# 0              1               3                  3
# 1              2               2                  4
# 2              3               3                  3
# 3              4               2                  3
# 4              5               3                  3
# ...          ...             ...                ...
# 4405        4406               3                  3
# 4406        4407               2                  3
# 4407        4408               3                  4
# 4408        4409               2                  3
# 4409        4410               4                  3
#
# [4410 rows x 3 columns]

# %%
f6=pd.read_csv(r'C:\Users\saura\Downloads\archive (20)\out_time.csv')
f6
# Out:
#       Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0              1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1              2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2              3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3              4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4              5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
# ...          ...         ...                  ...                  ...
# 4405        4406         NaN  2015-01-02 17:27:37  2015-01-05 19:08:20
# 4406        4407         NaN  2015-01-02 16:19:01                  NaN
# 4407        4408         NaN  2015-01-02 17:17:35  2015-01-05 17:08:07
# 4408        4409         NaN  2015-01-02 19:48:37  2015-01-05 19:37:40
# 4409        4410         NaN  2015-01-02 16:49:19  2015-01-05 17:33:02
#
#                2015-01-06           2015-01-07           2015-01-08  \
# ...

# %%
df=pd.concat([f1,f2,f3,f4,f5,f6],axis=1)
df
# Out:
#               Variable                                            Meaning  \
# 0                  Age                                Age of the employee
# 1            Attrition  Whether the employee left in the previous year...
# 2       BusinessTravel  How frequently the employees travelled for bus...
# 3           Department                              Department in company
# 4     DistanceFromHome                          Distance from home in kms
# ...                ...                                                ...
# 4405               NaN                                                NaN
# 4406               NaN                                                NaN
# 4407               NaN                                                NaN
# 4408               NaN                                                NaN
# 4409               NaN                                                NaN
#
#      Levels  EmployeeID  EnvironmentSatisfaction  JobSatisfaction  \
# ...

# %%
f1.append(f2)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_15436\3638450512.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   f1.append(f2)
#               Variable                                            Meaning  \
# 0                  Age                                Age of the employee
# 1            Attrition  Whether the employee left in the previous year...
# 2       BusinessTravel  How frequently the employees travelled for bus...
# 3           Department                              Department in company
# 4     DistanceFromHome                          Distance from home in kms
# ...                ...                                                ...
# 4405               NaN                                                NaN
# 4406               NaN                                                NaN
# 4407               NaN                                                NaN
# ...

# %%
f2.append(f3)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_15436\230540520.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   f2.append(f3)
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      NaN              NaN              NaN
# 4406        4407                      NaN              NaN              NaN
# ...

# %%
f3.append(f4)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_15436\2819256269.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   f3.append(f4)
#        Age Attrition     BusinessTravel              Department  \
# 0     51.0        No      Travel_Rarely                   Sales
# 1     31.0       Yes  Travel_Frequently  Research & Development
# 2     32.0        No  Travel_Frequently  Research & Development
# 3     38.0        No         Non-Travel  Research & Development
# 4     32.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 4405   NaN       NaN                NaN                     NaN
# 4406   NaN       NaN                NaN                     NaN
# 4407   NaN       NaN                NaN                     NaN
# 4408   NaN       NaN                NaN                     NaN
# ...

# %%
f4.append(f5)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_15436\2229066478.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   f4.append(f5)
#       Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0            1.0         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1            2.0         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2            3.0         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3            4.0         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4            5.0         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
# ...          ...         ...                  ...                  ...
# 4405         NaN         NaN                  NaN                  NaN
# 4406         NaN         NaN                  NaN                  NaN
# 4407         NaN         NaN                  NaN                  NaN
# ...

# %%
df=f5.append(f6)
df
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_15436\3501911591.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=f5.append(f6)
#       EmployeeID  JobInvolvement  PerformanceRating  Unnamed: 0  2015-01-01  \
# 0            1.0             3.0                3.0         NaN         NaN
# 1            2.0             2.0                4.0         NaN         NaN
# 2            3.0             3.0                3.0         NaN         NaN
# 3            4.0             2.0                3.0         NaN         NaN
# 4            5.0             3.0                3.0         NaN         NaN
# ...          ...             ...                ...         ...         ...
# 4405         NaN             NaN                NaN      4406.0         NaN
# 4406         NaN             NaN                NaN      4407.0         NaN
# ...
